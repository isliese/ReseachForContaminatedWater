# %%
# 2023 - 6월 정기조사 자료

# 라이브러리 import
import pandas as pd
import folium
from folium.plugins import MarkerCluster

data = pd.read_csv("latlon2.csv", encoding='cp949', low_memory=False)
rdt = data[['정점명(영어)', '정점명(한국어)', '위도', '경도', '평균', '134Cs', '3H']]
map = folium.Map(location=[36, 127], zoom_start=7, control_scale=True)

# csv 파일에서 데이터 불러오기
for i in rdt.index:
    name_eng = rdt.loc[i, '정점명(영어)']
    lat = rdt.loc[i, '위도']
    lon = rdt.loc[i, '경도']
    average = rdt.loc[i, '평균']
    Cs = rdt.loc[i, '134Cs']
    H = rdt.loc[i, '3H']

    # 평균값에 따라 circle marker 색 다르게 설정하기
    if average < 0.65:
        color = 'blue'
    elif 0.65 <= average < 0.7:
        color = 'green'
    elif 0.7 <= average < 0.75:
        color = 'yellow'
    elif 0.75 <= average < 0.8:
        color = 'orange'
    else:
        color = 'red'

    # circle marker 정보 표시하기
    folium.CircleMarker([lat, lon],
                      radius=average * 50,
                      popup = "정점명: " + name_eng + "\n세슘농도: " + str(Cs) + "(mBq/kg)\n삼중수소: " + str(H) + "(Bq/L)",
                      stroke=False,
                      color=color,  # Set the color based on the range
                      fill=True).add_to(map)

# 주변지역을 묶어서 대략적인 개수 분포를 볼 수 있도록 마커 클러스터 생성
mc = MarkerCluster()

for i in rdt.index:
    lat = rdt.loc[i, '위도']
    lon = rdt.loc[i, '경도']
    mc.add_child(folium.CircleMarker([lat, lon]))

# 클러스터를 맵에 추가
map.add_child(mc)

# 지도 표시
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17d63448f0220cd09856dd16a5ac9c91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17d63448f0220cd09856dd16a5ac9c91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17d63448f0220cd09856dd16a5ac9c91 = L.map(
#                 &quot;map_17d63448f0220cd09856dd16a5ac9c91&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_17d63448f0220cd09856dd16a5ac9c91);
#
#
#
#
#
#             var tile_layer_a012ea870e06123f2f84fb29c2e0e5c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_17d63448f0220cd09856dd16a5ac9c91);
#
#
#             var circle_marker_264e45fa63d43022d4fb4fa0cb9572d1 = L.circleMarker(
#                 [37.5375, 126.5861],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: NaN, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_17d63448f0220cd09856dd16a5ac9c91);
#
#
#         var popup_3a254764a33a8f80f2b3f029c0d6d38a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4677bea95e296655583371e6ad9c6b9 = $(`&lt;div id=&quot;html_e4677bea95e296655583371e6ad9c6b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;정점명: BC0102 세슘농도: nan(mBq/kg) 삼중수소: nan(Bq/L)&lt;/div&gt;`)[0];
#                 popup_3a254764a33a8f80f2b3f029c0d6d38a.setContent(html_e4677bea95e296655583371e6ad9c6b9);
#
#
#
#         circle_marker_264e45fa63d43022d4fb4fa0cb9572d1.bindPopup(popup_3a254764a33a8f80f2b3f029c0d6d38a)
#         ;
#
#
#
#
#             var circle_marker_bf40b08e220d6770a8e7950d6d165754 = L.circleMarker(
#                 [37.3264, 126.3533],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: NaN, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_17d63448f0220cd09856dd16a5ac9c91);
#
#
#         var popup_fbc978b76fa71455fe74b43a5f76b871 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e519fefad5809ea403baa67e4a4d0ee = $(`&lt;div id=&quot;html_4e519fefad5809ea403baa67e4a4d0ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;정점명: BC0113 세슘농도: nan(mBq/kg) 삼중수소: nan(Bq/L)&lt;/div&gt;`)[0];
#                 popup_fbc978b76fa71455fe74b43a5f76b871.setContent(html_4e519fefad5809ea403baa67e4a4d0ee);
#
#
#
#         circle_marker_bf40b08e220d6770a8e7950d6d165754.bindPopup(popup_fbc978b76fa71455fe74b43a5f76b871)
#         ;
#
#
#
#
#             var circle_marker_7567196f3fbdcb199b9bb1ba85f69167 = L.circleMarker(
#                 [35.2042, 126.4125],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: NaN, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_17d63448f0220cd09856dd16a5ac9c91);
#
#
#         var popup_90625c4efa5cdf9452aad0b432d5f2a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54c913cb05422235ec25c749e4f8f2f5 = $(`&lt;div id=&quot;html_54c913cb05422235ec25c749e4f8f2f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;정점명: BC0124 세슘농도: nan(mBq/k

# %%
# 2023 - 9월 긴급조사 자료

# 라이브러리 import
import pandas as pd
import folium
from folium.plugins import MarkerCluster

data = pd.read_csv("september.csv", encoding='cp949', low_memory=False)
rdt = data[['정점', '위도', '경도', '평균', '134Cs', '3H']]
map = folium.Map(location=[36, 127], zoom_start=7, control_scale=True)

# csv 파일에서 데이터 불러오기
for i in rdt.index:
    name_eng = rdt.loc[i, '정점']
    lat = rdt.loc[i, '위도']
    lon = rdt.loc[i, '경도']
    average = rdt.loc[i, '평균']
    Cs = rdt.loc[i, '134Cs']
    H = rdt.loc[i, '3H']

    # 평균값에 따라 circle marker 색 다르게 설정하기
    if average < 0.65:
        color = 'blue'
    elif 0.65 <= average < 0.7:
        color = 'green'
    elif 0.7 <= average < 0.75:
        color = 'yellow'
    elif 0.75 <= average < 0.8:
        color = 'orange'
    else:
        color = 'red'

    # circle marker 정보 표시하기
    folium.CircleMarker([lat, lon],
                      radius=average * 2,
                      popup = "정점명: " + name_eng + "\n세슘농도: " + str(Cs) + "(mBq/kg)\n삼중수소: " + str(H) + "(Bq/L)",
                      stroke=False,
                      color=color,  # Set the color based on the range
                      fill=True).add_to(map)

# 주변지역을 묶어서 대략적인 개수 분포를 볼 수 있도록 마커 클러스터 생성
mc = MarkerCluster()

for i in rdt.index:
    lat = rdt.loc[i, '위도']
    lon = rdt.loc[i, '경도']
    mc.add_child(folium.CircleMarker([lat, lon]))

# 클러스터를 맵에 추가
map.add_child(mc)

# 지도 표시
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c95bc24edbc286329e253f24c26774cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c95bc24edbc286329e253f24c26774cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c95bc24edbc286329e253f24c26774cc = L.map(
#                 &quot;map_c95bc24edbc286329e253f24c26774cc&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c95bc24edbc286329e253f24c26774cc);
#
#
#
#
#
#             var tile_layer_985e9acbd98e13a397aadaf850161bfa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c95bc24edbc286329e253f24c26774cc);
#
#
#             var circle_marker_4da6b4b81981a407d50018e7c77b3ed2 = L.circleMarker(
#                 [33.4953, 126.1803],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.981333334, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_c95bc24edbc286329e253f24c26774cc);
#
#
#         var popup_33e05cf1856fe5c6392236bd3ad9670c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c236d7b9815c71c5617e8bf482490345 = $(`&lt;div id=&quot;html_c236d7b9815c71c5617e8bf482490345&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;정점명: JE0101 세슘농도: 0.084(mBq/kg) 삼중수소: 6.7(Bq/L)&lt;/div&gt;`)[0];
#                 popup_33e05cf1856fe5c6392236bd3ad9670c.setContent(html_c236d7b9815c71c5617e8bf482490345);
#
#
#
#         circle_marker_4da6b4b81981a407d50018e7c77b3ed2.bindPopup(popup_33e05cf1856fe5c6392236bd3ad9670c)
#         ;
#
#
#
#
#             var circle_marker_833c36303cf656d15faeacbe4345f3c1 = L.circleMarker(
#                 [33.5447, 126.2497],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.510666666, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_c95bc24edbc286329e253f24c26774cc);
#
#
#         var popup_15c8e94619b5f5badba71b240afbd9e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fea76215a1dca099d51fe16ac153cf9c = $(`&lt;div id=&quot;html_fea76215a1dca099d51fe16ac153cf9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;정점명: JE0102 세슘농도: 0.081(mBq/kg) 삼중수소: 6.9(Bq/L)&lt;/div&gt;`)[0];
#                 popup_15c8e94619b5f5badba71b240afbd9e3.setContent(html_fea76215a1dca099d51fe16ac153cf9c);
#
#
#
#         circle_marker_833c36303cf656d15faeacbe4345f3c1.bindPopup(popup_15c8e94619b5f5badba71b240afbd9e3)
#         ;
#
#
#
#
#             var circle_marker_f2f13c229282da784d361a169049e394 = L.circleMarker(
#                 [33.5806, 126.3186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.180666666, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_c95bc24edbc286329e253f24c26774cc);
#
#
#         var popup_34eaabd0862656e9a5a350b141f16b75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_244d6caa3e02e6d39ecb436de7691ba3 = $(`&lt;div id=&quot;html_244d6caa3e02e6d39ecb436de7691ba3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;

# %%
# 2023 - 9월 긴급조사 자료 - 색상 기준 변경

# 라이브러리 import
import pandas as pd
import folium
from folium.plugins import MarkerCluster

data = pd.read_csv("september.csv", encoding='cp949', low_memory=False)
rdt = data[['정점', '위도', '경도', '평균', '134Cs', '3H']]
map = folium.Map(location=[36, 127], zoom_start=7, control_scale=True)

# csv 파일에서 데이터 불러오기
for i in rdt.index:
    name_eng = rdt.loc[i, '정점']
    lat = rdt.loc[i, '위도']
    lon = rdt.loc[i, '경도']
    average = rdt.loc[i, '평균']
    Cs = rdt.loc[i, '134Cs']
    H = rdt.loc[i, '3H']

    # 평균값에 따라 circle marker 색 다르게 설정하기
    if average < 8.0:
        color = 'blue'
    elif 8.0 <= average < 8.5:
        color = 'green'
    elif 8.5 <= average < 8.9:
        color = 'yellow'
    elif 8.9 <= average < 9.2:
        color = 'orange'
    else:
        color = 'red'

    # circle marker 정보 표시하기
    folium.CircleMarker([lat, lon],
                      radius=average * 2,
                      popup = "정점명: " + name_eng + "\n세슘농도: " + str(Cs) + "(mBq/kg)\n삼중수소: " + str(H) + "(Bq/L)",
                      stroke=False,
                      color=color,  # Set the color based on the range
                      fill=True).add_to(map)

# 주변지역을 묶어서 대략적인 개수 분포를 볼 수 있도록 마커 클러스터 생성
mc = MarkerCluster()

for i in rdt.index:
    lat = rdt.loc[i, '위도']
    lon = rdt.loc[i, '경도']
    mc.add_child(folium.CircleMarker([lat, lon]))

# 클러스터를 맵에 추가
map.add_child(mc)

# 지도 표시
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f10e1512f35969d11720095185fe30f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f10e1512f35969d11720095185fe30f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f10e1512f35969d11720095185fe30f1 = L.map(
#                 &quot;map_f10e1512f35969d11720095185fe30f1&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f10e1512f35969d11720095185fe30f1);
#
#
#
#
#
#             var tile_layer_c2a9ee7344258355ffc71bde7c9b6688 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f10e1512f35969d11720095185fe30f1);
#
#
#             var circle_marker_7c05a27d3743dbc01159f66fc9a9bfcf = L.circleMarker(
#                 [33.4953, 126.1803],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.981333334, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_f10e1512f35969d11720095185fe30f1);
#
#
#         var popup_ae7383372da58a5b690df4283fcccafb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c60c9475b6ae747880fe29e1dc23dd9c = $(`&lt;div id=&quot;html_c60c9475b6ae747880fe29e1dc23dd9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;정점명: JE0101 세슘농도: 0.084(mBq/kg) 삼중수소: 6.7(Bq/L)&lt;/div&gt;`)[0];
#                 popup_ae7383372da58a5b690df4283fcccafb.setContent(html_c60c9475b6ae747880fe29e1dc23dd9c);
#
#
#
#         circle_marker_7c05a27d3743dbc01159f66fc9a9bfcf.bindPopup(popup_ae7383372da58a5b690df4283fcccafb)
#         ;
#
#
#
#
#             var circle_marker_b69daa690214ea866431350928f003ed = L.circleMarker(
#                 [33.5447, 126.2497],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.510666666, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_f10e1512f35969d11720095185fe30f1);
#
#
#         var popup_cc7d6f8f49bcd5935d3630e61322a224 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc1e44540f25ee3ee175e083cc05d03b = $(`&lt;div id=&quot;html_fc1e44540f25ee3ee175e083cc05d03b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;정점명: JE0102 세슘농도: 0.081(mBq/kg) 삼중수소: 6.9(Bq/L)&lt;/div&gt;`)[0];
#                 popup_cc7d6f8f49bcd5935d3630e61322a224.setContent(html_fc1e44540f25ee3ee175e083cc05d03b);
#
#
#
#         circle_marker_b69daa690214ea866431350928f003ed.bindPopup(popup_cc7d6f8f49bcd5935d3630e61322a224)
#         ;
#
#
#
#
#             var circle_marker_bb88fc5b3d4ebcd8f4834f2d8da540ad = L.circleMarker(
#                 [33.5806, 126.3186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.180666666, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_f10e1512f35969d11720095185fe30f1);
#
#
#         var popup_6cc9e533bdc089977060753b46b868a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23aef9750f51ad8c284966c1dc433be2 = $(`&lt;div id=&quot;html_23aef9750f51ad8c284966c1dc433be2&quot; style=&quot;width: 100.0%; height: 1
